# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-+-Constants" data-toc-modified-id="Imports-+-Constants-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports + Constants</a></span></li><li><span><a href="#Load-histograms-(or-create-if-needed)" data-toc-modified-id="Load-histograms-(or-create-if-needed)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load histograms (or create if needed)</a></span><ul class="toc-item"><li><span><a href="#Split-NL-band" data-toc-modified-id="Split-NL-band-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Split NL band</a></span></li><li><span><a href="#Plot-histograms" data-toc-modified-id="Plot-histograms-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Plot histograms</a></span></li><li><span><a href="#Standardize-histograms" data-toc-modified-id="Standardize-histograms-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Standardize histograms</a></span></li></ul></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Dumb-Baseline-Models" data-toc-modified-id="Dumb-Baseline-Models-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Dumb Baseline Models</a></span><ul class="toc-item"><li><span><a href="#Incountry:-predict-country-mean" data-toc-modified-id="Incountry:-predict-country-mean-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Incountry: predict country mean</a></span></li><li><span><a href="#Linear-NL" data-toc-modified-id="Linear-NL-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Linear NL</a></span></li></ul></li><li><span><a href="#OOC-Predictions" data-toc-modified-id="OOC-Predictions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>OOC Predictions</a></span><ul class="toc-item"><li><span><a href="#rgb" data-toc-modified-id="rgb-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>rgb</a></span></li><li><span><a href="#ms" data-toc-modified-id="ms-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>ms</a></span></li><li><span><a href="#nl" data-toc-modified-id="nl-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>nl</a></span></li><li><span><a href="#msnl" data-toc-modified-id="msnl-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>msnl</a></span></li></ul></li><li><span><a href="#Incountry-Predictions" data-toc-modified-id="Incountry-Predictions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Incountry Predictions</a></span><ul class="toc-item"><li><span><a href="#Predict-country-mean" data-toc-modified-id="Predict-country-mean-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Predict country mean</a></span></li><li><span><a href="#Histogram-model" data-toc-modified-id="Histogram-model-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Histogram model</a></span></li></ul></li></ul></div>

# %% [markdown]
# ### clone repository (only needed when working in colab)

# %%
#! git clone https://github.com/sustainlab-group/africa_poverty.git

# %% [markdown]
# # Imports + Constants

# %%
# load autoreload to reload module before executing them
# %load_ext autoreload        
# %autoreload 2

# %matplotlib inline

# %%
from collections import defaultdict
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pickle
import pandas as pd
import seaborn as sns

#sys.path.append('/content/africa_poverty/')
from batchers import batcher, dataset_constants

#############################################################################
#EDIT:      import functions (plot_band_hists, plot_label_hist)
#           like it's done in dhs_baselines.ipynb
#############################################################################

from models.histograms import (
    get_per_image_histograms,
    plot_band_hists,
    plot_label_hist,
    split_nl_hist)


from models.linear_model import train_linear_logo
from utils.analysis import calc_score, evaluate
from utils.general import colordisplay, load_npz
from utils.plot import scatter_preds
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\redor\Anaconda3\envs\Model_Architecture_PS\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-abcf90e79f39>", line 12, in <module>
#     from batchers import batcher, dataset_constants
#
#   File "C:\Users\redor\Documents\THKoelnDIS\6.Semester\DIS22_ml_projekt\Model_Architecture_PS\batchers\batcher.py", line 1, in <module>
#     from batchers.dataset_constants import SIZES, SURVEY_NAMES, MEANS_DICT, STD_DEVS_DICT
#
#   File "C:\Users\redor\Documents\THKoelnDIS\6.Semester\DIS22_ml_projekt\Model_Architecture_PS\batchers\dataset_constants.py", line 140
#     'VIIRS': 2.322687,
#     ^
# SyntaxError: invalid syntax

# %%
SPLITS = ['train', 'val', 'test']
FOLDS = ['A', 'B', 'C', 'D', 'E']

DATASET_NAME = 'LSMS'               # select LSMS survey data
LABEL_NAME = 'wealthpooled'

# %% [markdown]
# # Load histograms (or create if needed)

# %%
# BAND_BIN_EDGES = [-10^5, -5.0, -4.9, -4.8, ..., 4.8, 4.9, 5.0, 10^5]
# BAND_BIN_CENTERS = [-5.05, -4.95, -4.85, ..., 4.85, 4.95, 5.05]

# set BAND_BIN_EDGES and BAND_BIN_CENTERS to above numpy arrays
BAND_BIN_EDGES = np.concatenate([
    [-1e5],
    np.arange(-5.0, 5.1, 0.1),
    [1e5]
])
BAND_BIN_CENTERS = np.arange(-5.05, 5.15, 0.1)

# LABEL_BIN_EDGES = [-2.0, -1.9, ..., 2.8, 2.9]
# LABEL_BIN_CENTERS = [-1.95, -1.85, ..., 2.75, 2.85]

# set LABEL_BIN_EDGES and LABEL_BIN_CENTERS to above numpy arrays
LABEL_BIN_EDGES = np.arange(-2.0, 3.0, 0.1)
LABEL_BIN_CENTERS = np.arange(-1.95, 2.95, 0.1)

# band name => color for plotting
BAND_COLORS = {
    'BLUE'  : 'blue',
    'GREEN' : 'green',
    'RED'   : 'red',
    'SWIR1' : 'purple',
    'SWIR2' : 'brown',
    'TEMP1' : 'orange',
    'NIR'   : 'pink',
    'NIGHTLIGHTS': 'black',
    'DMSP'  : 'black',
    'VIIRS' : 'gray',
}

# set order for band colors
BAND_ORDER = ['BLUE', 'GREEN', 'RED', 'SWIR1', 'SWIR2', 'TEMP1', 'NIR', 'NIGHTLIGHTS']
BAND_ORDER_NLSPLIT = ['BLUE', 'GREEN', 'RED', 'SWIR1', 'SWIR2', 'TEMP1', 'NIR', 'DMSP', 'VIIRS']

# create dictionary to assign indices from BAND_ORDER(_NLSPLIT) to channels
BANDS_DICT = {
    'rgb': [0, 1, 2],
    'rgbnl': [0, 1, 2, 7, 8],
    'ms': [0, 1, 2, 3, 4, 5, 6],
    'msnl': [0, 1, 2, 3, 4, 5, 6, 7, 8],
    'nl': [7, 8],
}

# %%
def get_batcher(tfrecord_files):
    '''

    Parameters
    ----------
    tfrecord_files --- list of str, paths to TFRecord files, sorted

    Returns ---  object from class Batcher
    -------

    '''
    return batcher.Batcher(
        tfrecord_files=tfrecord_files,  # path(s) to TFRecord files containing satellite images
        dataset=DATASET_NAME,           # key to MEANS_DICT with maps to dict containing the means and standard deviations calculated over the entire dataset (train + val + test),
                                        # with negative values set to 0, and ignoring any pixel that is 0 across all bands
        batch_size=128,
        ls_bands='ms',                  # 'ms': all 7 Landsat bands
        nl_band='merge',                # 'merge': single nightlights band
        label_name=LABEL_NAME,          # set label to wealthpooled
        shuffle=False,                  # don't shuffle
        augment=False,                  # don't use data augmentation
        negatives='zero',               # clip unexpected negative values to 0
        normalize=True)                 # subtract mean and divide by std_dev

# %%
# file path for LSMS histograms
file_path = '/content/africa_poverty/data/lsms_image_hists.npz'

# if histograms don't exist yet they are created here:
if not os.path.exists(file_path):
    tfrecord_paths = batcher.get_lsms_tfrecord_paths(dataset_constants.SURVEY_NAMES['LSMS'])    # get sorted list of paths to TFRecord files (containing satellite images)
                                                                                                # for all splits (train,val and test) from dataset LSMS
    init_iter, batch_op = get_batcher(tfrecord_paths).get_batch()                               # get Batch object from tfrecord_paths
    results = get_per_image_histograms(init_iter, batch_op, band_bin_edges=BAND_BIN_EDGES)      # create histograms per image
    print('Saving image histograms to', file_path)
    np.savez_compressed(file_path, **results)

# %%
result = load_npz(file_path)            # load histograms

# extract values for each key and save it to a separate variable
image_hists = result['image_hists']
labels = result['labels']
locs = result['locs']
years = result['years']
nls_center = result['nls_center']
nls_mean = result['nls_mean']
# Out:
# image_hists: dtype=int64, shape=(3020, 8, 102)
# labels: dtype=float32, shape=(3020,)
# locs: dtype=float32, shape=(3020, 2)
# years: dtype=int32, shape=(3020,)
# nls_center: dtype=float32, shape=(3020,)
# nls_mean: dtype=float32, shape=(3020,)

# %% [markdown]
# ## Split NL band

# %%
# split NL band
#2nd-to-last band is DMSP, last band is VIIRS
image_hists = split_nl_hist(image_hists, years)

# %% [markdown]
# ## Plot histograms

# %%
################################################################################
# EDIT:     remove definition of functions (plot_band_hists, plot_label_hist)
#           since they can be imported from models.histograms.py
################################################################################

# %%
################################################################################
# EDIT:     BAND_COLORS where missing in the plot_band_hists function
################################################################################

# plot all histograms
band_hists = np.sum(image_hists, axis=0, dtype=np.int64)  # shape [C, nbins]
plot_band_hists(
    band_hists, 
    BAND_ORDER_NLSPLIT,
    BAND_COLORS,
    BAND_BIN_CENTERS,
    xlabel='normalized pixel value', 
    ylabel='count', 
    title='pixel distributions - all', 
    yscale='log')
plot_label_hist(labels, LABEL_BIN_CENTERS, title='label distributions - all')

# %% [markdown]
# ## Standardize histograms

# %%
# standardize to 0 mean and unit variance
image_hists_mean = np.mean(image_hists, axis=0, dtype=np.float64)
image_hists_std = np.std(image_hists, axis=0, dtype=np.float64)
standardized_image_hists = (image_hists - image_hists_mean) / (image_hists_std + 1e-6)
print(standardized_image_hists.shape)
# Out:
# (3020, 9, 102)

# %% [markdown]
# # Load data

# %%
LSMS_CSV_PATH = '/content/africa_poverty/data/lsms_wealth_index.csv'
lsms_df = pd.read_csv(LSMS_CSV_PATH, float_precision='high')

# add tfrecords_index, nls_center, and nls_mean columns
def row_to_tfrecords_index(latlonyear):
    '''

    Args:
        -   latlonyear: pd.Series, shape: (3,)
            containing one row of the columns lat, lon, year

    Returns:
        - int, index of the combination of latitude,longitude and year in loc_to_tfrecords_index dictionary
    '''
    lat, lon, year = latlonyear
    lat, lon = np.float32(lat), np.float32(lon)
    return loc_to_tfrecords_index[(lat, lon, year)]

loc_to_tfrecords_index = {
    (lat, lon, year): i
    for i, ((lat, lon), year) in enumerate(zip(locs, years))
}

lsms_df['tfrecords_index'] = lsms_df[['lat', 'lon', 'year']].apply(row_to_tfrecords_index, axis=1, raw=True)
lsms_df['nls_center'] = nls_center[lsms_df['tfrecords_index']]
lsms_df['nls_mean'] = nls_mean[lsms_df['tfrecords_index']]

# %%
with pd.option_context('display.max_rows', 6):
    display(lsms_df)
# Out:
#            lat        lon  year  ... tfrecords_index  nls_center  nls_mean
# 0    -0.292248  31.478722  2005  ...            2574   -0.161126 -0.161126
# 1    -0.292248  31.478722  2009  ...            2694   -0.161126 -0.161126
# 2    -0.292248  31.478722  2013  ...            2941   -0.083399 -0.081302
# ...        ...        ...   ...  ...             ...         ...       ...
# 3017  9.917938  11.689417  2015  ...            1626   -0.078012 -0.076090
# 3018  9.991906  37.692553  2011  ...             120   -0.161126 -0.161126
# 3019  9.991906  37.692553  2015  ...             449   -0.082880 -0.081012
#
# [3020 rows x 23 columns]

# %%
# save nl values to CSV
# lsms_nl_df = lsms_df[['lat', 'lon', 'year', 'country', 'nls_center', 'nls_mean']]
# lsms_nl_df.to_csv('../data/lsms_nls.csv', index=False)

# %%
LSMS_COUNTRIES = ['ethiopia', 'malawi', 'nigeria', 'tanzania', 'uganda'] # select LSMS countries (these could be imported from dataset_constants.py?)

# convert lat/lon to float32
for col in ['lat', 'lon']:
    lsms_df[col] = lsms_df[col].astype(np.float32)

# create mapping: loc => country
loc_to_country = (lsms_df
    .groupby(['lat', 'lon'])
    .apply(lambda df: df['country'].iloc[0])
    .to_dict())

country_indices = defaultdict(list)  # country => np.array of indices
country_labels = np.zeros(len(lsms_df), dtype=np.int32)  # np.array of country labels


for i, loc in enumerate(locs):              #loop through locations->np.array(lat,lon) (index and value)
    country = loc_to_country[tuple(loc)]    # get country for location
    country_indices[country].append(i)      # get all indices for country

for i, country in enumerate(LSMS_COUNTRIES):                            # loop through all LSMS countries (index and value)
    country_indices[country] = np.asarray(country_indices[country])     # cast index lists of all countries into numpy arrays
    indices = country_indices[country]                                  # get all indices for country
    country_labels[indices] = i                                         # map indices to country index

# %%
loc_to_country
# Out:
# {(-16.98550033569336, 35.249900817871094): 'malawi',
#  (-16.600000381469727, 34.96730041503906): 'malawi',
#  (-16.26689910888672, 34.895198822021484): 'malawi',
#  (-16.198200225830078, 35.15800094604492): 'malawi',
#  (-16.113399505615234, 35.40919876098633): 'malawi',
#  (-16.08799934387207, 35.06809997558594): 'malawi',
#  (-16.083200454711914, 35.582401275634766): 'malawi',
#  (-16.057899475097656, 35.23619842529297): 'malawi',
#  (-16.037500381469727, 35.35449981689453): 'malawi',
#  (-16.02039909362793, 34.920101165771484): 'malawi',
#  (-15.949899673461914, 35.11360168457031): 'malawi',
#  (-15.855199813842773, 35.073699951171875): 'malawi',
#  (-15.829500198364258, 35.26179885864258): 'malawi',
#  (-15.828399658203125, 35.35319900512695): 'malawi',
#  (-15.823399543762207, 35.0885009765625): 'malawi',
#  (-15.808600425720215, 35.05720138549805): 'malawi',
#  (-15.777600288391113, 35.040199279785156): 'malawi',
#  (-15.769499778747559, 34.99689865112305): 'malawi',
#  (-15.737000465393066, 34.38520050048828): 'malawi',
#  (-15.730799674987793, 35.0713005065918): 'malawi',
#  (-10.456999778747559, 39.07661819458008): 'tanzania',
#  (-10.43340015411377, 39.77962875366211): 'tanzania',
#  (-10.386590003967285, 39.988861083984375): 'tanzania',
#  (-10.334970474243164, 40.22397994995117): 'tanzania',
#  (-10.311989784240723, 40.1469612121582): 'tanzania',
#  (-10.298629760742188, 39.8851318359375): 'tanzania',
#  (-10.28557014465332, 40.19746017456055): 'tanzania',
#  (-10.27433967590332, 40.188140869140625): 'tanzania',
#  (-10.271320343017578, 40.17414093017578): 'tanzania',
#  (-10.238719940185547, 38.92237854003906): 'tanzania',
#  (-10.23449993133545, 39.28192901611328): 'tanzania',
#  (-10.224320411682129, 37.87675857543945): 'tanzania',
#  (-10.13092041015625, 39.996421813964844): 'tanzania',
#  (-10.114319801330566, 39.244388580322266): 'tanzania',
#  (-10.098759651184082, 35.902950286865234): 'tanzania',
#  (-10.084230422973633, 34.57978820800781): 'tanzania',
#  (-10.078590393066406, 34.65861129760742): 'tanzania',
#  (-10.071809768676758, 38.93770980834961): 'tanzania',
#  (-10.049440383911133, 39.702640533447266): 'tanzania',
#  (-10.02511978149414, 38.890159606933594): 'tanzania',
#  (-9.993619918823242, 39.683231353759766): 'tanzania',
#  (-9.9753999710083, 33.92599868774414): 'malawi',
#  (-9.971599578857422, 33.3739013671875): 'malawi',
#  (-9.922980308532715, 39.32835006713867): 'tanzania',
#  (-9.822159767150879, 34.45354080200195): 'tanzania',
#  (-9.803609848022461, 37.981048583984375): 'tanzania',
#  (-9.800979614257812, 37.89751052856445): 'tanzania',
#  (-9.638179779052734, 33.96001052856445): 'tanzania',
#  (-9.595120429992676, 37.403099060058594): 'tanzania',
#  (-9.504460334777832, 33.230201721191406): 'malawi',
#  (-9.479180335998535, 33.12928009033203): 'tanzania',
#  (-9.430410385131836, 33.06618881225586): 'tanzania',
#  (-9.427490234375, 33.973899841308594): 'tanzania',
#  (-9.280349731445312, 34.71855163574219): 'tanzania',
#  (-9.27083969116211, 33.60054016113281): 'tanzania',
#  (-9.246479988098145, 33.35498809814453): 'tanzania',
#  (-9.167909622192383, 33.54330062866211): 'tanzania',
#  (-9.159589767456055, 33.830509185791016): 'tanzania',
#  (-9.147040367126465, 32.880210876464844): 'tanzania',
#  (-9.138460159301758, 33.33795166015625): 'tanzania',
#  (-9.106229782104492, 39.56222152709961): 'tanzania',
#  (-9.065179824829102, 34.793209075927734): 'tanzania',
#  (-8.976869583129883, 33.95320129394531): 'tanzania',
#  (-8.929189682006836, 39.53435134887695): 'tanzania',
#  (-8.910499572753906, 33.5713996887207): 'tanzania',
#  (-8.894960403442383, 33.50244903564453): 'tanzania',
#  (-8.890520095825195, 33.0212287902832): 'tanzania',
#  (-8.886630058288574, 33.134681701660156): 'tanzania',
#  (-8.826539993286133, 38.87871170043945): 'tanzania',
#  (-8.74722957611084, 39.415199279785156): 'tanzania',
#  (-8.736479759216309, 36.72077178955078): 'tanzania',
#  (-8.724430084228516, 31.967010498046875): 'tanzania',
#  (-3.2043800354003906, 35.928199768066406): 'tanzania',
#  (-3.2015600204467773, 34.09928894042969): 'tanzania',
#  (-3.196660041809082, 37.615379333496094): 'tanzania',
#  (-3.194089889526367, 33.49076843261719): 'tanzania',
#  (-3.1686699390411377, 31.948259353637695): 'tanzania',
#  (-3.1514599323272705, 31.895750045776367): 'tanzania',
#  (-3.1111600399017334, 37.596439361572266): 'tanzania',
#  (-3.0966598987579346, 37.63920974731445): 'tanzania',
#  (-3.061429977416992, 33.754459381103516): 'tanzania',
#  (-2.9963901042938232, 36.01396179199219): 'tanzania',
#  (-2.8970999717712402, 34.13228988647461): 'tanzania',
#  (-2.8861498832702637, 30.786340713500977): 'tanzania',
#  (-2.8295700550079346, 30.460290908813477): 'tanzania',
#  (-2.721719980239868, 33.78028869628906): 'tanzania',
#  (-2.6306099891662598, 31.96993064880371): 'tanzania',
#  (-2.628119945526123, 33.31538009643555): 'tanzania',
#  (-2.493269920349121, 32.91048049926758): 'tanzania',
#  (-2.4912099838256836, 30.58424949645996): 'tanzania',
#  (-2.141050100326538, 35.74726104736328): 'tanzania',
#  (-2.057960033416748, 31.45509910583496): 'tanzania',
#  (-2.0334200859069824, 33.868831634521484): 'tanzania',
#  (-2.017009973526001, 32.86827850341797): 'tanzania',
#  (-1.814229965209961, 30.943540573120117): 'tanzania',
#  (-1.6396700143814087, 31.720800399780273): 'tanzania',
#  (-1.5709099769592285, 31.672040939331055): 'tanzania',
#  (-1.5640900135040283, 34.073760986328125): 'tanzania',
#  (-1.5111700296401978, 33.77141189575195): 'tanzania',
#  (-1.4985500574111938, 31.076730728149414): 'tanzania',
#  (-1.3394500017166138, 31.7877197265625): 'tanzania',
#  (-1.3385000228881836, 31.684680938720703): 'tanzania',
#  (-1.3356499671936035, 31.822940826416016): 'tanzania',
#  (-1.324779987335205, 34.3549690246582): 'tanzania',
#  (-1.2552160024642944, 30.056819915771484): 'uganda',
#  (-1.2414300441741943, 29.961166381835938): 'uganda',
#  (-1.213420033454895, 31.66550064086914): 'tanzania',
#  (-1.2130099534988403, 31.46394920349121): 'tanzania',
#  (-1.1505999565124512, 29.67283821105957): 'uganda',
#  (-1.0587799549102783, 30.697010040283203): 'tanzania',
#  (-0.9871770143508911, 30.12983512878418): 'uganda',
#  (-0.9823369979858398, 30.45973777770996): 'uganda',
#  (-0.9649009704589844, 29.959688186645508): 'uganda',
#  (-0.9203240275382996, 29.80122947692871): 'uganda',
#  (-0.9036269783973694, 31.765472412109375): 'uganda',
#  (-0.8871250152587891, 31.711088180541992): 'uganda',
#  (-0.8676630258560181, 30.354114532470703): 'uganda',
#  (-0.8608070015907288, 30.269275665283203): 'uganda',
#  (-0.7605710029602051, 30.179094314575195): 'uganda',
#  (-0.7450389862060547, 30.424814224243164): 'uganda',
#  (-0.6974380016326904, 30.477415084838867): 'uganda',
#  (-0.6404309868812561, 29.80598258972168): 'uganda',
#  (-0.6392310261726379, 31.529987335205078): 'uganda',
#  (-0.6087610125541687, 30.672229766845703): 'uganda',
#  (7.583729267120361, 6.181607246398926): 'nigeria',
#  (7.586397647857666, 3.563823938369751): 'nigeria',
#  (7.588610649108887, 39.794593811035156): 'ethiopia',
#  (7.591868877410889, 6.23380184173584): 'nigeria',
#  (7.601650714874268, 5.000195026397705): 'nigeria',
#  (7.616270065307617, 5.205151081085205): 'nigeria',
#  (7.622063636779785, 5.3776397705078125): 'nigeria',
#  (7.628427505493164, 5.73993444442749): 'nigeria',
#  (7.634249687194824, 4.254446983337402): 'nigeria',
#  (7.636332988739014, 4.788572788238525): 'nigeria',
#  (7.646913051605225, 34.256282806396484): 'ethiopia',
#  (7.655364036560059, 7.282270908355713): 'nigeria',
#  (7.658160209655762, 38.09463119506836): 'ethiopia',
#  (7.669123649597168, 36.925537109375): 'ethiopia',
#  (7.672117233276367, 35.84001159667969): 'ethiopia',
#  (7.692628860473633, 37.73361587524414): 'ethiopia',
#  (7.705384731292725, 37.65053939819336): 'ethiopia',
#  (7.722999572753906, 5.723021507263184): 'nigeria',
#  (7.731696128845215, 37.49858474731445): 'ethiopia',
#  (7.735205173492432, 8.477535247802734): 'nigeria',
#  ...}

# %%
valid_mask = lsms_df['n'].notna()                               # set validation mask to filter out empty columns
dmsp_mask = valid_mask & (lsms_df['year'] < 2012)               # set mask for years before 2012 for dmsp
viirs_mask = valid_mask & (lsms_df['year'] >= 2012)             # set mask for years since 2012 for viirs
uganda_mask = lsms_df['n'].notna() & (lsms_df['country'] == 'uganda') & (lsms_df['year'].isin([2005, 2009])) # set mask for uganda

labels_new = lsms_df.loc[valid_mask, 'index_rep'].values
country_labels_new = lsms_df.loc[valid_mask, 'country'].values
years_new = lsms_df.loc[valid_mask, 'year'].values

# %% [markdown]
# # Dumb Baseline Models

# %% [markdown]
# ## Incountry: predict country mean

# %%
mean_preds = np.zeros_like(labels_new)                          # create empty np array to save country mean predictions to
for country in LSMS_COUNTRIES:
    mask = (country_labels_new == country)
    mean_preds[mask] = np.mean(labels_new[mask])                # get mean value from all labels that match this country
r2, _, _, _ = evaluate(labels_new, mean_preds, do_print=True)   # evaluate prediction of country mean by 4 rank measurements
# Out:
# r^2: 0.564, R^2: 0.564, mse: 0.324, rank: 0.757

# %%
scatter_preds(labels_new, preds=mean_preds, by_name='country', by_col=country_labels_new)

# %% [markdown]
# ## Linear NL

# %%
def linear_nl():
    '''

    Displays a DataFrame in table style
    containing the parameters:
        - sensor
        - nl_type
        - whether a weighting was used
    and the r2 value calculated with the above

    '''
    linear_nl_df = pd.DataFrame(columns=['sensor', 'nl_type', 'weighted', 'r2'])                                    #create DataFrame
    linear_nl_df.set_index(['sensor', 'nl_type', 'weighted'], inplace=True)

    for sensor, mask in [('dmsp', dmsp_mask), ('viirs', viirs_mask)]:                                               # first get dsmp then viirs
        for nl_type in ['nls_center', 'nls_mean']:                                                                  # first get center then mean
            for weighted, w in [(False, None), (True, lsms_df.loc[mask, 'n'])]:                                     # first non-weighted then weighted
                linear_nl_df.loc[(sensor, nl_type, weighted)] = calc_score(                                         # set r^2 values in dataframe for indices 
                    lsms_df.loc[mask, 'index_rep'], lsms_df.loc[mask, nl_type], metric='r2', weights=w)
    display(linear_nl_df.unstack('weighted'))

linear_nl()

print('Uganda nls_center, r^2 =',
      calc_score(lsms_df.loc[uganda_mask, 'nls_center'], lsms_df.loc[uganda_mask, 'index_rep'], metric='r2'))
print('Uganda nls_mean, r^2 =',
      calc_score(lsms_df.loc[uganda_mask, 'nls_mean'], lsms_df.loc[uganda_mask, 'index_rep'], metric='r2'))
# Out:
#                          r2
# weighted              False     True
# sensor nl_type
# dmsp   nls_center  0.034556  0.028925
#        nls_mean    0.083379  0.070432
# viirs  nls_center  0.097060  0.112499
#        nls_mean    0.067228  0.066957
# Uganda nls_center, r^2 = 0.27474847707977446
# Uganda nls_mean, r^2 = 0.2998109155183803

# %%
fig, axs = plt.subplots(1, 3, figsize=(7, 3), constrained_layout=True)
lsms_df.loc[dmsp_mask].plot.scatter(
    x='index_rep', y='nls_mean', s=lsms_df.loc[dmsp_mask, 'n'], ax=axs[0],
    label='weighted $r^2 = 0.07$')
lsms_df.loc[viirs_mask].plot.scatter(
    x='index_rep', y='nls_mean', s=lsms_df.loc[viirs_mask, 'n'], ax=axs[1],
    label='weighted $r^2 = 0.07$')
lsms_df.loc[uganda_mask].plot.scatter(
    x='index_rep', y='nls_mean', s=lsms_df.loc[uganda_mask, 'n'], ax=axs[2],
    label='weighted $r^2 = 0.30$')
axs[0].set_title('DMSP')
axs[1].set_title('VIIRS')
axs[2].set_title('Uganda 2005-09')
for ax in axs:
    ax.grid(True)
    ax.legend()

# %% [markdown]
# # OOC Predictions

# %%
def run_ooc(country, band_indices):
    '''

    Args:
        - country: str, name of country
        - band_indices: list of int, index of selected channels

    Returns:
        - results_df:   pd.DataFrame, columns are ['r2', 'R2', 'mse', 'rank']
                        row index are `cols`

    '''
    nbands = len(band_indices)                         # get no of bands
    nbins = len(BAND_BIN_CENTERS)                      # get number of bins
    test_group = LSMS_COUNTRIES.index(country)         # get index of test group (country)
############################################################################################
#EDIT:    changed 'normalized_image_hists' to 'standardized_image_hists' since
#         there is no variable called 'normalized_image_hists'
############################################################################################
    num_examples = len(standardized_image_hists)      # get number of test group (country)
    test_preds, coefs, intercept = train_linear_logo(
        features=standardized_image_hists[:, band_indices, :].reshape(num_examples, -1), 
        labels=labels,
        group_labels=country_labels,
        cv_groups=[i for i in range(len(LSMS_COUNTRIES)) if test_group != i], # cross validation labels
        test_groups=[test_group],
        plot=True, 
        group_names=LSMS_COUNTRIES, 
        return_weights=True)
    print('best intercept:', intercept)
    per_band_coefs = coefs.reshape(nbands, nbins)

############################################################################################
#EDIT:    added BAND COLORS as parameter to plot_band_hists since it was missing
############################################################################################
#plot Ridge Regression Weights per Band for selected country
    plot_band_hists(per_band_coefs, 
        np.asarray(BAND_ORDER_NLSPLIT)[band_indices], 
        BAND_COLORS,
        BAND_BIN_CENTERS,
        xlabel='normalized pixel value', 
        ylabel='weight', 
        title='Ridge Regression Weights per Band', 
        yscale='linear')
    return evaluate(test_preds, labels[country_indices[country]], do_print=True)

# %%
len(standardized_image_hists)
# Out:
# 3020

# %% [markdown]
# ## rgb

# %%
rgb_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
rgb_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    rgb_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['rgb'])
# Out:
# === ethiopia ===
# best val mse: 0.796, best alpha: 1024.0, test mse: 1.149
# best intercept: 0.27665382385248505
# r^2: 0.003, R^2: -12.699, mse: 1.149, rank: -0.099
# === malawi ===
# best val mse: 1.002, best alpha: 1024.0, test mse: 0.248
# best intercept: 0.05904070623287575
# r^2: 0.037, R^2: -3.736, mse: 0.248, rank: 0.170
# === nigeria ===
# best val mse: 0.591, best alpha: 17179869184.0, test mse: 1.870
# best intercept: -0.3135659352767565
# r^2: 0.000, R^2: -141996216512211.438, mse: 1.870, rank: 0.094
# === tanzania ===
# best val mse: 1.492, best alpha: 128.0, test mse: 0.617
# best intercept: 0.14841169455581227
# r^2: 0.218, R^2: -0.052, mse: 0.617, rank: 0.492
# === uganda ===
# best val mse: 1.190, best alpha: 1024.0, test mse: 0.522
# best intercept: 0.060024751315156465
# r^2: 0.009, R^2: -8.317, mse: 0.522, rank: 0.055

# %%
colordisplay(rgb_df)
# Out:
# <style  type="text/css" >
# #T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col1,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col1,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col2,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col0,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col1,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col3,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col2{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col3,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col2,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col0,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col0,#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col2{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col3{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col3{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col2{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col3{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }</style><table id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002level0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col0" class="data row0 col0" >0.002752</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col1" class="data row0 col1" >-12.698867</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col2" class="data row0 col2" >1.149377</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row0_col3" class="data row0 col3" >-0.098550</td>
#             </tr>
#             <tr>
#                         <th id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col0" class="data row1 col0" >0.037049</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col1" class="data row1 col1" >-3.735721</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col2" class="data row1 col2" >0.247897</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row1_col3" class="data row1 col3" >0.169638</td>
#             </tr>
#             <tr>
#                         <th id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002level0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col0" class="data row2 col0" >0.000292</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col1" class="data row2 col1" >-141996216512211.437500</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col2" class="data row2 col2" >1.869667</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row2_col3" class="data row2 col3" >0.093880</td>
#             </tr>
#             <tr>
#                         <th id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col0" class="data row3 col0" >0.217606</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col1" class="data row3 col1" >-0.052298</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col2" class="data row3 col2" >0.616936</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row3_col3" class="data row3 col3" >0.492312</td>
#             </tr>
#             <tr>
#                         <th id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002level0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col0" class="data row4 col0" >0.009124</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col1" class="data row4 col1" >-8.316848</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col2" class="data row4 col2" >0.521783</td>
#                         <td id="T_ef3597dc_a90c_11eb_a036_0242ac1c0002row4_col3" class="data row4 col3" >0.055100</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## ms

# %%
ms_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
ms_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    ms_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['ms'])
# Out:
# === ethiopia ===
# best val mse: 0.834, best alpha: 8192.0, test mse: 1.435
# best intercept: 0.307940844271197
# r^2: 0.000, R^2: -16.165, mse: 1.435, rank: -0.095
# === malawi ===
# best val mse: 1.156, best alpha: 8192.0, test mse: 0.183
# best intercept: 0.06870725539382323
# r^2: 0.121, R^2: -4.622, mse: 0.183, rank: 0.357
# === nigeria ===
# best val mse: 0.499, best alpha: 1024.0, test mse: 1.803
# best intercept: -0.3052154253656201
# r^2: 0.092, R^2: -11.446, mse: 1.803, rank: 0.312
# === tanzania ===
# best val mse: 1.573, best alpha: 17179869184.0, test mse: 0.401
# best intercept: 0.13493993774708507
# r^2: 0.082, R^2: -333709375606.974, mse: 0.401, rank: 0.342
# === uganda ===
# best val mse: 1.300, best alpha: 1024.0, test mse: 0.537
# best intercept: 0.03960880183052784
# r^2: 0.046, R^2: -4.044, mse: 0.537, rank: 0.149

# %%
colordisplay(ms_df)
# Out:
# <style  type="text/css" >
# #T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col0,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col3,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col2,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col1,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col0,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col1,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col3,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col1,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col2,#T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col2{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col0{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col3{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col0{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col2{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col3{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col0{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col2{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col3{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }</style><table id="T_07b8def4_a90d_11eb_a036_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_07b8def4_a90d_11eb_a036_0242ac1c0002level0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col0" class="data row0 col0" >0.000476</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col1" class="data row0 col1" >-16.165160</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col2" class="data row0 col2" >1.434538</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row0_col3" class="data row0 col3" >-0.094659</td>
#             </tr>
#             <tr>
#                         <th id="T_07b8def4_a90d_11eb_a036_0242ac1c0002level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col0" class="data row1 col0" >0.121195</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col1" class="data row1 col1" >-4.622024</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col2" class="data row1 col2" >0.183500</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row1_col3" class="data row1 col3" >0.356824</td>
#             </tr>
#             <tr>
#                         <th id="T_07b8def4_a90d_11eb_a036_0242ac1c0002level0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col0" class="data row2 col0" >0.092469</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col1" class="data row2 col1" >-11.445585</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col2" class="data row2 col2" >1.802538</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row2_col3" class="data row2 col3" >0.312422</td>
#             </tr>
#             <tr>
#                         <th id="T_07b8def4_a90d_11eb_a036_0242ac1c0002level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col0" class="data row3 col0" >0.081744</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col1" class="data row3 col1" >-333709375606.974426</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col2" class="data row3 col2" >0.400714</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row3_col3" class="data row3 col3" >0.342041</td>
#             </tr>
#             <tr>
#                         <th id="T_07b8def4_a90d_11eb_a036_0242ac1c0002level0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col0" class="data row4 col0" >0.046051</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col1" class="data row4 col1" >-4.043800</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col2" class="data row4 col2" >0.536555</td>
#                         <td id="T_07b8def4_a90d_11eb_a036_0242ac1c0002row4_col3" class="data row4 col3" >0.149028</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## nl

# %%
nl_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
nl_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    nl_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['nl'])
# Out:
# === ethiopia ===
# best val mse: 0.755, best alpha: 1024.0, test mse: 0.939
# best intercept: 0.26349741566925267
# r^2: 0.044, R^2: -45.934, mse: 0.939, rank: 0.242
# === malawi ===
# best val mse: 0.834, best alpha: 128.0, test mse: 0.335
# best intercept: 0.10007132704437025
# r^2: 0.599, R^2: 0.054, mse: 0.335, rank: 0.644
# === nigeria ===
# best val mse: 0.332, best alpha: 128.0, test mse: 1.381
# best intercept: -0.25445136713784566
# r^2: 0.280, R^2: -3.690, mse: 1.381, rank: 0.481
# === tanzania ===
# best val mse: 1.053, best alpha: 128.0, test mse: 0.355
# best intercept: 0.15474021108706495
# r^2: 0.489, R^2: 0.124, mse: 0.355, rank: 0.596
# === uganda ===
# best val mse: 1.017, best alpha: 128.0, test mse: 0.293
# best intercept: 0.05819219461884264
# r^2: 0.454, R^2: 0.211, mse: 0.293, rank: 0.598

# %%
colordisplay(nl_df)
# Out:
# <style  type="text/css" >
# #T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col0,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col1,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col3,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col2,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col3{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col0,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col1,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col3,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col2,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col1,#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col2{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col1{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col0{
#             background-color:  #ed8366;
#             color:  #000000;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col3{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col0{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col3{
#             background-color:  #da5a49;
#             color:  #000000;
#         }</style><table id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002level0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col0" class="data row0 col0" >0.044168</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col1" class="data row0 col1" >-45.933638</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col2" class="data row0 col2" >0.939187</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row0_col3" class="data row0 col3" >0.241722</td>
#             </tr>
#             <tr>
#                         <th id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col0" class="data row1 col0" >0.599337</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col1" class="data row1 col1" >0.053813</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col2" class="data row1 col2" >0.335454</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row1_col3" class="data row1 col3" >0.644350</td>
#             </tr>
#             <tr>
#                         <th id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002level0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col0" class="data row2 col0" >0.279512</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col1" class="data row2 col1" >-3.689884</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col2" class="data row2 col2" >1.380689</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row2_col3" class="data row2 col3" >0.481245</td>
#             </tr>
#             <tr>
#                         <th id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col0" class="data row3 col0" >0.488784</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col1" class="data row3 col1" >0.123997</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col2" class="data row3 col2" >0.355392</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row3_col3" class="data row3 col3" >0.596115</td>
#             </tr>
#             <tr>
#                         <th id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002level0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col0" class="data row4 col0" >0.454391</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col1" class="data row4 col1" >0.210772</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col2" class="data row4 col2" >0.293278</td>
#                         <td id="T_7659d3d6_a90d_11eb_a036_0242ac1c0002row4_col3" class="data row4 col3" >0.597761</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## msnl

# %%
msnl_df = pd.DataFrame(columns=['country', 'r2', 'R2', 'mse', 'rank'], dtype=np.float64)
msnl_df.set_index('country', inplace=True)

for country in LSMS_COUNTRIES:
    print(f'=== {country} ===')
    msnl_df.loc[country, :] = run_ooc(country, band_indices=BANDS_DICT['msnl'])
# Out:
# === ethiopia ===
# best val mse: 0.777, best alpha: 1024.0, test mse: 1.087
# best intercept: 0.27027126903068477
# r^2: 0.007, R^2: -8.950, mse: 1.087, rank: 0.033
# === malawi ===
# best val mse: 0.984, best alpha: 1024.0, test mse: 0.123
# best intercept: 0.07020686238412881
# r^2: 0.522, R^2: 0.472, mse: 0.123, rank: 0.647
# === nigeria ===
# best val mse: 0.312, best alpha: 1024.0, test mse: 1.627
# best intercept: -0.29656884557521945
# r^2: 0.315, R^2: -5.988, mse: 1.627, rank: 0.588
# === tanzania ===
# best val mse: 1.305, best alpha: 1024.0, test mse: 0.386
# best intercept: 0.14007206626805574
# r^2: 0.399, R^2: 0.159, mse: 0.386, rank: 0.566
# === uganda ===
# best val mse: 1.108, best alpha: 1024.0, test mse: 0.375
# best intercept: 0.04333089862176057
# r^2: 0.317, R^2: -0.502, mse: 0.375, rank: 0.369

# %%
colordisplay(msnl_df)
# Out:
# <style  type="text/css" >
# #T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col0,#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col1,#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col3,#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col2{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col0,#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col1,#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col3,#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col0{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col1{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col3{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col0{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col1{
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col2{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col3{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col1{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col2{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col3{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }</style><table id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002level0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col0" class="data row0 col0" >0.006696</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col1" class="data row0 col1" >-8.950155</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col2" class="data row0 col2" >1.086593</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row0_col3" class="data row0 col3" >0.032632</td>
#             </tr>
#             <tr>
#                         <th id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col0" class="data row1 col0" >0.521540</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col1" class="data row1 col1" >0.472225</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col2" class="data row1 col2" >0.122880</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row1_col3" class="data row1 col3" >0.647481</td>
#             </tr>
#             <tr>
#                         <th id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002level0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col0" class="data row2 col0" >0.315273</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col1" class="data row2 col1" >-5.988177</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col2" class="data row2 col2" >1.626808</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row2_col3" class="data row2 col3" >0.587517</td>
#             </tr>
#             <tr>
#                         <th id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col0" class="data row3 col0" >0.398929</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col1" class="data row3 col1" >0.158528</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col2" class="data row3 col2" >0.386328</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row3_col3" class="data row3 col3" >0.566405</td>
#             </tr>
#             <tr>
#                         <th id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002level0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col0" class="data row4 col0" >0.316965</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col1" class="data row4 col1" >-0.501745</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col2" class="data row4 col2" >0.374977</td>
#                         <td id="T_70c1d9d2_a90d_11eb_a036_0242ac1c0002row4_col3" class="data row4 col3" >0.368807</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Incountry Predictions

# %%
# load incountry folds
file_path = '/content/africa_poverty/data/lsms_incountry_folds.pkl'
with open(file_path, 'rb') as f:
    incountry_folds = pickle.load(f)

# %%
num_examples = len(image_hists)
incountry_group_labels = np.zeros(num_examples, dtype=np.int32)
for i, f in enumerate(FOLDS):
    test_indices = incountry_folds[f]['test']
    incountry_group_labels[test_indices] = i

# %% [markdown]
# ## Predict country mean

# %%
mean_preds = np.zeros(num_examples)
for i, country in enumerate(LSMS_COUNTRIES):
    indices = np.where(country_labels == i)[0]
    mean_preds[indices] = np.mean(labels[indices])
r2, R2, mse, rank = evaluate(labels, mean_preds, do_print=True)
# Out:
# r^2: 0.551, R^2: 0.551, mse: 0.337, rank: 0.748

# %%
scatter_preds(
    labels=labels,
    preds=mean_preds,
    by_name='country',
    by_col=np.asarray(LSMS_COUNTRIES)[country_labels])

# %% [markdown]
# ## Histogram model

# %%
def run_incountry(features, labels, incountry_group_labels):
    '''

    Args:
        - features: np.array, shape [N, C*nbins]
        - labels: tf.Tensor, shape [batch_size] dtype=flaot32
        - incountry_group_labels: np.array, shape [N,] dtype=int32

    Returns:
        - ndarray, test predictions

    '''
    num_examples = len(features)
    test_preds = np.zeros(num_examples, dtype=np.float32)

    do_plot = True
    for i, fold in enumerate(FOLDS):
        print('Fold:', fold)
        test_indices = incountry_folds[fold]['test']
        test_preds[test_indices] = train_linear_logo(
            features=features,
            labels=labels,
            group_labels=incountry_group_labels,
            cv_groups=[x for x in range(5) if x != i],
            test_groups=[i],
            plot=do_plot,
            group_names=FOLDS)
        do_plot = False
    return test_preds

# %%
############################################################################################
#EDIT:    changed 'normalized_image_hists' to 'standardized_image_hists' since
#         there is no variable called 'normalized_image_hists'
############################################################################################
test_preds = run_incountry(
    standardized_image_hists.reshape(num_examples, -1), labels, incountry_group_labels)
# Out:
# Fold: A
# best val mse: 0.348, best alpha: 1024.0, test mse: 0.373
# Fold: B
# best val mse: 0.359, best alpha: 1024.0, test mse: 0.348
# Fold: C
# best val mse: 0.355, best alpha: 1024.0, test mse: 0.353
# Fold: D
# best val mse: 0.364, best alpha: 1024.0, test mse: 0.319
# Fold: E
# best val mse: 0.356, best alpha: 1024.0, test mse: 0.340

# %%
test_preds_df = pd.DataFrame(data={
    'preds': test_preds,
    'labels': labels,
    'country': np.asarray(LSMS_COUNTRIES)[country_labels],
    'year': years
})
with pd.option_context('display.max_rows', 4):
    display(test_preds_df)
# Out:
#          preds    labels   country  year
# 0    -0.744204 -1.232088  ethiopia  2011
# 1    -0.163558 -0.869557  ethiopia  2011
# ...        ...       ...       ...   ...
# 3018  1.015059  1.379230    uganda  2013
# 3019  1.070682  1.180093    uganda  2013
#
# [3020 rows x 4 columns]

# %%
def evaluate_df(df):
    '''
    Args
    - df: pd.DataFrame, contains columns ['preds', 'labels']

    Returns: pd.Series, index ['r2', 'R2', 'mse', 'rank']
    '''
    r2, R2, mse, rank = evaluate(df['preds'], df['labels'])
    return pd.Series({'r2': r2, 'R2': R2, 'mse': mse, 'rank': rank})

results_bycountry_df = test_preds_df.groupby('country').apply(evaluate_df)
results_bycountry_df.loc['all', :] = evaluate_df(test_preds_df)
colordisplay(results_bycountry_df)
# Out:
# <style  type="text/css" >
# #T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col0,#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col1,#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col3,#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col2{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col0{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col1,#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col2,#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col0,#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col3{
#             background-color:  #e67259;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col0{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col1{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col3{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col0{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col1{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col2{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col3{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col0{
#             background-color:  #f59f80;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col1{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col2{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col3{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col2{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }</style><table id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002level0_row0" class="row_heading level0 row0" >ethiopia</th>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col0" class="data row0 col0" >0.022593</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col1" class="data row0 col1" >-2.405881</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col2" class="data row0 col2" >0.368855</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row0_col3" class="data row0 col3" >0.158077</td>
#             </tr>
#             <tr>
#                         <th id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002level0_row1" class="row_heading level0 row1" >malawi</th>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col0" class="data row1 col0" >0.535267</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col1" class="data row1 col1" >0.477263</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col2" class="data row1 col2" >0.115779</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row1_col3" class="data row1 col3" >0.639102</td>
#             </tr>
#             <tr>
#                         <th id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002level0_row2" class="row_heading level0 row2" >nigeria</th>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col0" class="data row2 col0" >0.294455</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col1" class="data row2 col1" >-0.560100</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col2" class="data row2 col2" >0.467210</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row2_col3" class="data row2 col3" >0.561145</td>
#             </tr>
#             <tr>
#                         <th id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002level0_row3" class="row_heading level0 row3" >tanzania</th>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col0" class="data row3 col0" >0.446941</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col1" class="data row3 col1" >0.292438</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col2" class="data row3 col2" >0.263773</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row3_col3" class="data row3 col3" >0.585378</td>
#             </tr>
#             <tr>
#                         <th id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002level0_row4" class="row_heading level0 row4" >uganda</th>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col0" class="data row4 col0" >0.402968</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col1" class="data row4 col1" >-0.487912</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col2" class="data row4 col2" >0.295996</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row4_col3" class="data row4 col3" >0.486439</td>
#             </tr>
#             <tr>
#                         <th id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002level0_row5" class="row_heading level0 row5" >all</th>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col0" class="data row5 col0" >0.537903</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col1" class="data row5 col1" >0.103460</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col2" class="data row5 col2" >0.346778</td>
#                         <td id="T_edeca8ba_a90d_11eb_a036_0242ac1c0002row5_col3" class="data row5 col3" >0.732542</td>
#             </tr>
#     </tbody></table>

# %%
results_bycy_df = test_preds_df.groupby(['country', 'year']).apply(evaluate_df)
colordisplay(results_bycy_df)
# Out:
# <style  type="text/css" >
# #T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col0{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col1{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col2,#T_eece969e_a90d_11eb_a036_0242ac1c0002row8_col1{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col3{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col0,#T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col1,#T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col3,#T_eece969e_a90d_11eb_a036_0242ac1c0002row3_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col2,#T_eece969e_a90d_11eb_a036_0242ac1c0002row10_col3{
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col0{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col1,#T_eece969e_a90d_11eb_a036_0242ac1c0002row3_col1{
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col2{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col3{
#             background-color:  #ed8366;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row3_col0,#T_eece969e_a90d_11eb_a036_0242ac1c0002row3_col3,#T_eece969e_a90d_11eb_a036_0242ac1c0002row5_col2,#T_eece969e_a90d_11eb_a036_0242ac1c0002row6_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row4_col0{
#             background-color:  #f6bea4;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row4_col1{
#             background-color:  #e7745b;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row4_col2{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row4_col3{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row5_col0{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row5_col1{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row5_col3,#T_eece969e_a90d_11eb_a036_0242ac1c0002row8_col2{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row6_col0{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row6_col2{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row6_col3{
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row7_col0{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row7_col1{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row7_col2{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row7_col3{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row8_col0{
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row8_col3{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row9_col0{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row9_col1{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row9_col2{
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row9_col3{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row10_col0{
#             background-color:  #f59f80;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row10_col1{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_eece969e_a90d_11eb_a036_0242ac1c0002row10_col2{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }</style><table id="T_eece969e_a90d_11eb_a036_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r2</th>        <th class="col_heading level0 col1" >R2</th>        <th class="col_heading level0 col2" >mse</th>        <th class="col_heading level0 col3" >rank</th>    </tr>    <tr>        <th class="index_name level0" >country</th>        <th class="index_name level1" >year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eece969e_a90d_11eb_a036_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>ethiopia</th>
#                         <th id="T_eece969e_a90d_11eb_a036_0242ac1c0002level1_row0" class="row_heading level1 row0" >2011</th>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col0" class="data row0 col0" >0.026422</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col1" class="data row0 col1" >-2.191288</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col2" class="data row0 col2" >0.350807</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row0_col3" class="data row0 col3" >0.158622</td>
#             </tr>
#             <tr>
#                                 <th id="T_eece969e_a90d_11eb_a036_0242ac1c0002level1_row1" class="row_heading level1 row1" >2015</th>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col0" class="data row1 col0" >0.012007</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col1" class="data row1 col1" >-2.807536</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col2" class="data row1 col2" >0.386903</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row1_col3" class="data row1 col3" >0.111944</td>
#             </tr>
#             <tr>
#                         <th id="T_eece969e_a90d_11eb_a036_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>malawi</th>
#                         <th id="T_eece969e_a90d_11eb_a036_0242ac1c0002level1_row2" class="row_heading level1 row2" >2010</th>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col0" class="data row2 col0" >0.505063</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col1" class="data row2 col1" >0.478634</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col2" class="data row2 col2" >0.135936</td>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row2_col3" class="data row2 col3" >0.578753</td>
#             </tr>
#             <tr>
#                                 <th id="T_eece969e_a90d_11eb_a036_0242ac1c0002level1_row3" class="row_heading level1 row3" >2016</th>
#                         <td id="T_eece969e_a90d_11eb_a036_0242ac1c0002row3_col0" class="data row3 col0" >0.582981</td>
#                         <td id=
